# %%
import numpy as np
import matplotlib.pyplot as plt
from random import choice, sample

# %%
top_left = [(1039, 164), (973, 215), (875, 266), (782, 329), (691, 397), (591, 467), (503, 541), (403, 600), (339, 654)] #avg x: -88, y: +60

# %%
x_top_left = np.linspace( top_left[0][0], top_left[-1][0], 100 ).astype(int)
y_top_left = np.linspace( top_left[0][1], top_left[-1][1], 100 ).astype(int)


new = list(zip(x_top_left, y_top_left))
new[::20]
# Out:
# [(np.int64(1039), np.int64(164)),
#  (np.int64(897), np.int64(262)),
#  (np.int64(756), np.int64(361)),
#  (np.int64(614), np.int64(460)),
#  (np.int64(473), np.int64(559))]

# %%
green_zone = {
    "top_left": [(1039, 164), (339, 654)],
    "top_right": [(1548, 67), (2410, 711)],
    "bot_left": [(296, 728), (904, 1214)],
    "bot_right": [(2424, 722), (1779, 1210)]
}

# %%
deploy = choice(list(green_zone))
deploy, green_zone[deploy][0][-1]
# Out:
# ('bot_left', 728)

# %%
green_zone.keys()
# Out:
# dict_keys(['top_left', 'top_right', 'bot_left', 'bot_right'])

# %%
deploy_type = 2
troops = [2, [10, 4] ]

green_zone = {
"top_left": [(1039, 164), (339, 654)],
"top_right": [(1548, 67), (2410, 711)],
"bot_left": [(296, 728), (904, 1214)],
"bot_right": [(2424, 722), (1779, 1210)]
}
if deploy_type == 1:
    deploy_pos = green_zone[choice(list(green_zone))]
    x = np.linspace( deploy_pos[0][0], deploy_pos[-1][0], 100 ).astype(int)
    y = np.linspace( deploy_pos[0][1], deploy_pos[-1][1], 100 ).astype(int)
    coor = list(zip(x, y))

else:
    coor = []
    for key in list(green_zone):
        avg = int(sum(troops[1])/4) + 1
        x = np.linspace( green_zone[key][0][0], green_zone[key][-1][0], 30 ).astype(int)
        y = np.linspace( green_zone[key][0][1], green_zone[key][-1][1], 30 ).astype(int)
        coor.append( sample(list(zip(x, y)), avg) )
    coor = [row for rows in coor for row in rows]

# %%
len(coor)
# Out:
# 16

# %%
for each in coor:
    print(each)
# Out:
# [(np.int64(918), np.int64(248)), (np.int64(894), np.int64(265)), (np.int64(580), np.int64(485)), (np.int64(339), np.int64(654))]
# [(np.int64(1904), np.int64(333)), (np.int64(2320), np.int64(644)), (np.int64(1964), np.int64(377)), (np.int64(1577), np.int64(89))]
# [(np.int64(862), np.int64(1180)), (np.int64(442), np.int64(845)), (np.int64(421), np.int64(828)), (np.int64(400), np.int64(811))]
# [(np.int64(1845), np.int64(1159)), (np.int64(2246), np.int64(856)), (np.int64(2045), np.int64(1008)), (np.int64(1934), np.int64(1092))]

# %%
attack_mode = False
lobby = True

if not lobby and attack_mode: print("jj")

# %%
green_zone = {
"top_left": [(1039, 164), (339, 654)],
"top_right": [(1548, 67), (2410, 711)],
"bot_left": [(296, 728), (904, 1214)],
"bot_right": [(2424, 722), (1779, 1210)]
}
if deploy_type == 1:
    deploy_pos = green_zone[choice(list(green_zone))]
    x = np.linspace( deploy_pos[0][0], deploy_pos[-1][0], 100 ).astype(int)
    y = np.linspace( deploy_pos[0][1], deploy_pos[-1][1], 100 ).astype(int)
    coor = list(zip(x, y))
# Out:
# 1
# 2
# 3
